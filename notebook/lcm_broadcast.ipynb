# %%
import lcm

# %%
import forseti2

# %%
lc = lcm.LCM("udpm://239.255.76.67:7667?ttl=1")

# %%
msg = forseti2.health()

# %%
msg.uptime = 0

# %%
msg.uptime+=1
lc.publish("sprocket/health", msg.encode())
